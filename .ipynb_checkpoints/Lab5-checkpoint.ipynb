# %%
# Load tidyverse
library(tidyverse)

# Load and view the data
milk <- read.csv('state_milk_production.csv')

#add new column to work in millions for milk_produced column
milk <- milk %>%
  mutate(milk_million = milk_produced/1000000)

# Extract the data for 1970 only
milk1970 <- milk %>%
  filter(year == 1970)

# %%
#looking at distribution of milk1970
ggplot(data = milk1970, aes(x = milk_million)) +
  geom_histogram(bins = 20) + 
  ggtitle('Histogram of milk produced in 1970 by state')
# Out:
# plot without title

# %%
#identifying the state that produced over 15 billion pounds of milk
filter(milk1970,milk_million>15000)
# Out:
#   region      state     year milk_produced milk_million
# 1 Lake States Wisconsin 1970 1.8435e+10    18435

# %%
#probability density plot as opposed to histogram for milk1970 distribution 
ggplot(data = milk1970, aes(x = milk_million)) +
  geom_density() + 
  ggtitle('Distribution estimate of milk produced in 1970 by state')
# Out:
# plot without title

# %%
#Another kind of plot that is useful for comparing 
#univariate distributions across different groups are 
#boxplots. For example, we can filter the data for
#three years, say 1970, 1990, and 2010, to visualize
#how the distribution of milk procutions changes across those years.

# Extract data for the years 1970, 1990, and 2010
boxMilk <- milk %>%
  filter(year %in% c('1970','1990','2010'))

ggplot(data = boxMilk, aes(x = as.factor(year), y = milk_million, fill = as.factor(year))) +
  geom_boxplot() + 
  ggtitle('Pounds of milk produced at the state-level') + 
  scale_fill_discrete(name = 'Year') + 
  xlab('Year') +
  ylab('Milk Produced (Millions lb)')
# Out:
# plot without title

# %%
#extracting medians from the boxplots above for each year
median_year <- boxMilk %>%
  group_by(year) %>%
  summarise(Med = median(milk_million)) %>%
  as_tibble()
median_year
# Out:
#   year Med
# 1 1970 1216.0
# 2 1990 1406.5
# 3 2010 1281.5

# %%
#looking at production over time by state

milksub <- milk %>%
  filter(state %in% c('New York','Wyoming','Maryland','Maine','Florida')) %>%
  select(state, year, milk_million)

ggplot(data = milksub, aes(x = year, y = milk_million, color = state)) +
  geom_point() + 
  ggtitle('Pounds of milk over time by state') +
  xlab('Year') +
  ylab('Milk Produced (Million lb)')
# Out:
# plot without title

# %%
#correlations between year and milk production for the 5 states 
cor_sum <- milksub %>%
  group_by(state) %>%
  summarise(Correlation = cor(year,milk_million)) %>%
  as_tibble()
cor_sum
# Out:
#   state    Correlation
# 1 Florida   0.6477052
# 2 Maine    -0.4039569
# 3 Maryland -0.9336690
# 4 New York  0.9088291
# 5 Wyoming  -0.2445134

# %%
#Display the distribution of the yearly milk production (in millions of pounds) for 1997
milk1997 <- milk %>%
  filter(year == 1997)

ggplot(data = milk1997, aes(x = milk_million)) +
  geom_density() + 
  ggtitle('Distribution estimate of milk produced in 1997 by state')
# Out:
# plot without title

# %%
#Report the average milk produced by each state
milk1997 %>%
summarize(Average = mean(milk_million))

#Report the median milk produced be each state
milk1997 %>%
summarize(Median = median(milk_million))
# Out:
#   Average
# 1 3121.82
#   Median
# 1 1436

# %%
#Report the state that produced the most milk
milk1997 %>% arrange(desc(milk_million))
# Out:
#    region          state          year milk_produced milk_million
# 1  Pacific         California     1997 2.7582e+10    27582
# 2  Lake States     Wisconsin      1997 2.2368e+10    22368
# 3  Northeast       New York       1997 1.1530e+10    11530
# 4  Northeast       Pennsylvania   1997 1.0662e+10    10662
# 5  Lake States     Minnesota      1997 9.2100e+09     9210
# 6  Southern Plains Texas          1997 5.7680e+09     5768
# 7  Lake States     Michigan       1997 5.4100e+09     5410
# 8  Pacific         Washington     1997 5.3050e+09     5305
# 9  Mountain        Idaho          1997 5.1930e+09     5193
# 10 Corn Belt       Ohio           1997 4.4150e+09     4415
# 11 Mountain        New Mexico     1997 4.0110e+09     4011
# 12 Corn Belt       Iowa           1997 3.6930e+09     3693
# 13 Mountain        Arizona        1997 2.6640e+09     2664
# 14 Northeast       Vermont        1997 2.6000e+09     2600
# 15 Southeast       Florida        1997 2.4760e+09     2476
# 16 Corn Belt       Missouri       1997 2.3620e+09     2362
# 17 Corn Belt       Illinois       1997 2.2030e+09     2203
# 18 Corn Belt       Indiana        1997 2.1890e+09     2189
# 19 Appalachian     Virginia       1997 1.8580e+09     1858
# 20 Appalachian     Kentucky       1997 1.8150e+09     1815
# 21 Mountain        Colorado       1997 1.6790e+09     1679
# 22 Pacific         Oregon         1997 1.6100e+09     1610
# 23 Appalachian     Tennessee      1997 1.6090e+09     1609
# 24 Mountain        Utah           1997 1.5400e+09     1540
# 25 Southeast       Georgia        1997 1.4880e+09     1488
# 26 Northern Plains South Dakota   1997 1.3840e+09     1384
# 27 Northeast       Maryland       1997 1.3260e+09     1326
# 28 Appalachian     North Carolina 1997 1.3040e+09     1304
# 29 Northern Plains Kansas         1997 1.2850e+09     1285
# 30 Southern Plains Oklahoma       1997 1.2490e+09     1249
# 31 Northern Plains Nebraska       1997 1.0400e+09     1040
# 32 Delta States    Louisiana      1997 7.9400e+08      794
# 33 Northern Plains North Dakota   1997 7.1300e+08      713
# 34 Northeast       Maine          1997 6.6200e+08      662
# 35 Delta States    Arkansas       1997 6.3500e+08      635
# 36 Delta States    Mississippi    1997 6.3400e+08      634
# 37 Northeast       Connecticut    1997 5.0900e+08      509
# 38 Mountain        Nevada         1997 4.7700e+08      477
# 39 Northeast       Massachusetts  1997 4.3400e+08      434
# 40 Southeast       Alabama        1997 4.1800e+08      418
# 41 Southeast       South Carolina 1997 3.9700e+08      397
# 42 Northeast       New Hampshire  1997 3.2800e+08      328
# 43 Northeast       New Jersey     1997 2.9900e+08      299
# 44 Mountain        Montana        1997 2.9500e+08      295
# 45 Appalachian     West Virginia  1997 2.6600e+08      266
# 46 Northeast       Delaware       1997 1.4800e+08      148
# 47 Pacific         Hawaii         1997 1.2300e+08      123
# 48 Mountain        Wyoming        1997 8.4000e+07       84
# 49 Northeast       Rhode Island   1997 3.2000e+07       32
# 50 Pacific         Alaska         1997 1.5000e+07       15

# %%
#Report the state that produced the least amount of milk
milk1997 %>% arrange(milk_million)
# Out:
#    region          state          year milk_produced milk_million
# 1  Pacific         Alaska         1997 1.5000e+07       15
# 2  Northeast       Rhode Island   1997 3.2000e+07       32
# 3  Mountain        Wyoming        1997 8.4000e+07       84
# 4  Pacific         Hawaii         1997 1.2300e+08      123
# 5  Northeast       Delaware       1997 1.4800e+08      148
# 6  Appalachian     West Virginia  1997 2.6600e+08      266
# 7  Mountain        Montana        1997 2.9500e+08      295
# 8  Northeast       New Jersey     1997 2.9900e+08      299
# 9  Northeast       New Hampshire  1997 3.2800e+08      328
# 10 Southeast       South Carolina 1997 3.9700e+08      397
# 11 Southeast       Alabama        1997 4.1800e+08      418
# 12 Northeast       Massachusetts  1997 4.3400e+08      434
# 13 Mountain        Nevada         1997 4.7700e+08      477
# 14 Northeast       Connecticut    1997 5.0900e+08      509
# 15 Delta States    Mississippi    1997 6.3400e+08      634
# 16 Delta States    Arkansas       1997 6.3500e+08      635
# 17 Northeast       Maine          1997 6.6200e+08      662
# 18 Northern Plains North Dakota   1997 7.1300e+08      713
# 19 Delta States    Louisiana      1997 7.9400e+08      794
# 20 Northern Plains Nebraska       1997 1.0400e+09     1040
# 21 Southern Plains Oklahoma       1997 1.2490e+09     1249
# 22 Northern Plains Kansas         1997 1.2850e+09     1285
# 23 Appalachian     North Carolina 1997 1.3040e+09     1304
# 24 Northeast       Maryland       1997 1.3260e+09     1326
# 25 Northern Plains South Dakota   1997 1.3840e+09     1384
# 26 Southeast       Georgia        1997 1.4880e+09     1488
# 27 Mountain        Utah           1997 1.5400e+09     1540
# 28 Appalachian     Tennessee      1997 1.6090e+09     1609
# 29 Pacific         Oregon         1997 1.6100e+09     1610
# 30 Mountain        Colorado       1997 1.6790e+09     1679
# 31 Appalachian     Kentucky       1997 1.8150e+09     1815
# 32 Appalachian     Virginia       1997 1.8580e+09     1858
# 33 Corn Belt       Indiana        1997 2.1890e+09     2189
# 34 Corn Belt       Illinois       1997 2.2030e+09     2203
# 35 Corn Belt       Missouri       1997 2.3620e+09     2362
# 36 Southeast       Florida        1997 2.4760e+09     2476
# 37 Northeast       Vermont        1997 2.6000e+09     2600
# 38 Mountain        Arizona        1997 2.6640e+09     2664
# 39 Corn Belt       Iowa           1997 3.6930e+09     3693
# 40 Mountain        New Mexico     1997 4.0110e+09     4011
# 41 Corn Belt       Ohio           1997 4.4150e+09     4415
# 42 Mountain        Idaho          1997 5.1930e+09     5193
# 43 Pacific         Washington     1997 5.3050e+09     5305
# 44 Lake States     Michigan       1997 5.4100e+09     5410
# 45 Southern Plains Texas          1997 5.7680e+09     5768
# 46 Lake States     Minnesota      1997 9.2100e+09     9210
# 47 Northeast       Pennsylvania   1997 1.0662e+10    10662
# 48 Northeast       New York       1997 1.1530e+10    11530
# 49 Lake States     Wisconsin      1997 2.2368e+10    22368
# 50 Pacific         California     1997 2.7582e+10    27582
